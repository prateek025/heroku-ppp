# %%
import pandas as pd

# %%
pdf_seen = pd.read_csv('C:/Web App-Flask-Powerplant/powerplant-random.csv')
#pdf_seen = pd.read_csv('C:/Web App-Flask-Powerplant/powerplant-seen.csv')

# %%
from pycaret.classification import *

# %%
exp1 = setup(data=pdf_seen, target='Class', train_size=0.8, session_id=42)
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_ca18ff42_c86d_11ea_a3e9_00c2c6da5cea" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ca18ff42_c86d_11ea_a3e9_00c2c6da5cealevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ca18ff42_c86d_11ea_a3e9_00c2c6da5cearow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_ca18ff42_c86d_11ea_a3e9_00c2c6da5cearow0_col1" class="data row0 col1" >42</td>
#             </tr>
#             <tr>
#                         <th id="T_ca18ff42_c86d_11ea_a3e9_00c2c6da5cealevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_ca18ff42_c86d_11ea_a3e9_00c2c6da5cearow1_col0" class="data row1 col0" >Target Type</td>
# ...

# %%
compare_models(blacklist=['knn', 'catboost', 'gbc'], sort='AUC', turbo=True)
# Out:
# <style  type="text/css" >
#     #T_3d08ac74_c86b_11ea_8847_00c2c6da5cea th {
#           text-align: left;
#     }    #T_3d08ac74_c86b_11ea_8847_00c2c6da5cearow0_col0 {
#             text-align:  left;
#         }    #T_3d08ac74_c86b_11ea_8847_00c2c6da5cearow0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_3d08ac74_c86b_11ea_8847_00c2c6da5cearow0_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_3d08ac74_c86b_11ea_8847_00c2c6da5cearow0_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_3d08ac74_c86b_11ea_8847_00c2c6da5cearow0_col4 {
#             : ;
#             text-align:  left;
#         }    #T_3d08ac74_c86b_11ea_8847_00c2c6da5cearow0_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_3d08ac74_c86b_11ea_8847_00c2c6da5cearow0_col6 {
#             background-color:  yellow;
# ...

# %%
m1 = create_model('et')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.8225  0.8928  0.7457  0.8269  0.7842  0.6341
# 1       0.7600  0.8462  0.6358  0.7692  0.6962  0.5008
# 2       0.7525  0.8542  0.6647  0.7372  0.6991  0.4898
# 3       0.7975  0.8784  0.7399  0.7805  0.7596  0.5849
# 4       0.7775  0.8611  0.6994  0.7658  0.7311  0.5420
# 5       0.8350  0.9159  0.8035  0.8129  0.8081  0.6634
# 6       0.7775  0.8750  0.7126  0.7607  0.7359  0.5440
# 7       0.8075  0.8909  0.7414  0.8012  0.7701  0.6050
# 8       0.7950  0.8586  0.7299  0.7840  0.7560  0.5796
# 9       0.7975  0.8752  0.7069  0.8039  0.7523  0.5822
# Mean    0.7922  0.8748  0.7180  0.7842  0.7493  0.5726
# SD      0.0247  0.0199  0.0440  0.0258  0.0334  0.0521

# %%
tuned_m1 = tune_model(estimator='et', n_iter=20, optimize='AUC')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.8375  0.8975  0.7457  0.8600  0.7988  0.6636
# 1       0.7625  0.8525  0.6647  0.7566  0.7077  0.5091
# 2       0.7825  0.8578  0.6821  0.7867  0.7307  0.5498
# 3       0.8175  0.8842  0.7341  0.8247  0.7768  0.6233
# 4       0.7900  0.8657  0.6821  0.8027  0.7375  0.5644
# 5       0.8375  0.9141  0.7746  0.8375  0.8048  0.6660
# 6       0.8050  0.8796  0.7184  0.8117  0.7622  0.5980
# 7       0.8025  0.8997  0.7241  0.8025  0.7613  0.5936
# 8       0.7950  0.8619  0.6954  0.8067  0.7469  0.5762
# 9       0.7925  0.8807  0.7069  0.7935  0.7477  0.5725
# Mean    0.8023  0.8794  0.7128  0.8083  0.7574  0.5917
# SD      0.0223  0.0191  0.0317  0.0269  0.0286  0.0465

# %%
final_m1 = finalize_model(tuned_m1)

# %%
save_model(final_m1, model_name = 'C:/Web App-Flask-Powerplant/deploy_powerplant-mini')
#save_model(final_m1, model_name = 'C:/Web App-Flask-Powerplant/deploy_powerplant')
# Out:
# Transformation Pipeline and Model Succesfully Saved

# %%
#import requests
#url = 'https://pycaret-insurance.herokuapp.com/predict_api'
#pred = requests.post(url,json={'age':55, 'sex':'male', 'bmi':59, 'children':1, 'smoker':'male', 'region':'northwest'})
#{'WeekDay':, 'Period':, 'NSW_Price':, 'NSW_Demand':, 'Vic_Price':, 'VIC_Demand':, 'Transfer':}
#print(pred.json())

#    data = request.get_json(force=True)
#    data_unseen = pd.DataFrame([data])
#    prediction1 = predict_model(model, data=data_unseen)
#    prediction1 = int(prediction1.Label[0])
#    for i in len(prediction1):
#        value = prediction1[i]
#        if value == 0 :
#            prediction[i] = 'DOWN'
#        else :
#            prediction[i] = 'UP'

if value == 0 :
    prediction[i] = 'DOWN'
else :
    prediction[i] = 'UP'
